# %% [markdown]
# <a href="https://colab.research.google.com/github/cizred/taiwan-license-plate-number-recognition/blob/main/first_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 車牌辨識

# %%
# !pip install ultralytics roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2G3jQOdUOXUBCmAt77di")
project = rf.workspace().project("taiwan-license-plate-recognition")
dataset = project.version(1).download("yolov8", overwrite=True)

from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.train(data=dataset.path+"/data.yaml", epochs=100, imgsz=640)
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipython-input-1399776208.py in <cell line: 0>()
#       4 rf = Roboflow(api_key="2G3jQOdUOXUBCmAt77di")
#       5 project = rf.workspace().project("taiwan-license-plate-recognition")
# ----> 6 dataset = project.version(1).download("yolov8", overwrite=True)
#       7
#       8 from ultralytics import YOLO
#
# /usr/local/lib/python3.12/dist-packages/roboflow/core/version.py in download(self, model_format, location, overwrite)
#     240
#     241         self.__download_zip(link, location, model_format)
# --> 242         self.__extract_zip(location, model_format)
#     243         self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
#     244
#
# ...
